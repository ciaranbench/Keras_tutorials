# %%
"""
Title: Timeseries classification from scratch
Author: [hfawaz](https://github.com/hfawaz/)
Date created: 2020/07/21
Last modified: 2021/07/16
Description: Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive.
"""
"""
## Introduction
This example shows how to do timeseries classification from scratch, starting from raw
CSV timeseries files on disk. We demonstrate the workflow on the FordA dataset from the
[UCR/UEA archive](https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/).
"""

"""
## Setup
"""

from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
"""
## Load the data: the FordA dataset
### Dataset description
The dataset we are using here is called FordA.
The data comes from the UCR archive.
The dataset contains 3601 training instances and another 1320 testing instances.
Each timeseries corresponds to a measurement of engine noise captured by a motor sensor.
For this task, the goal is to automatically detect the presence of a specific issue with
the engine. The problem is a balanced binary classification task. The full description of
this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).
### Read the TSV data
We will use the `FordA_TRAIN` file for training and the
`FordA_TEST` file for testing. The simplicity of this dataset
allows us to demonstrate effectively how to use ConvNets for timeseries classification.
In this file, the first column corresponds to the label.
"""


def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %%
"""
## Visualize the data
Here we visualize one timeseries example for each class in the dataset.
"""

classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

"""
## Standardize the data
Our timeseries are already in a single length (500). However, their values are
usually in various ranges. This is not ideal for a neural network;
in general we should seek to make the input values normalized.
For this specific dataset, the data is already z-normalized: each timeseries sample
has a mean equal to zero and a standard deviation equal to one. This type of
normalization is very common for timeseries classification problems, see
[Bagnall et al. (2016)](https://link.springer.com/article/10.1007/s10618-016-0483-9).
Note that the timeseries data used here are univariate, meaning we only have one channel
per timeseries example.
We will therefore transform the timeseries into a multivariate one with one channel
using a simple reshaping via numpy.
This will allow us to construct a model that is easily applicable to multivariate time
series.
"""

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

"""
Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
the number of classes beforehand.
"""

num_classes = len(np.unique(y_train))

"""
Now we shuffle the training set because we will be using the `validation_split` option
later when training.
"""

idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

"""
Standardize the labels to positive integers.
The expected labels will then be 0 and 1.
"""

y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
"""
## Build a model
We build a Fully Convolutional Neural Network originally proposed in
[this paper](https://arxiv.org/abs/1611.06455).
The implementation is based on the TF 2 version provided
[here](https://github.com/hfawaz/dl-4-tsc/).
The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found
via random search using [KerasTuner](https://github.com/keras-team/keras-tuner).
"""


def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])

# %%
"""
## Train the model
"""

epochs = 50
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/50
# 90/90 [==============================] - 7s 64ms/step - loss: 0.5680 - sparse_categorical_accuracy: 0.6917 - val_loss: 0.8428 - val_sparse_categorical_accuracy: 0.4577 - lr: 0.0010
# Epoch 2/50
# 90/90 [==============================] - 6s 72ms/step - loss: 0.4468 - sparse_categorical_accuracy: 0.7781 - val_loss: 0.9810 - val_sparse_categorical_accuracy: 0.4577 - lr: 0.0010
# Epoch 3/50
# 90/90 [==============================] - 6s 66ms/step - loss: 0.4505 - sparse_categorical_accuracy: 0.7736 - val_loss: 1.0298 - val_sparse_categorical_accuracy: 0.4577 - lr: 0.0010
# Epoch 4/50
# 90/90 [==============================] - 7s 75ms/step - loss: 0.4106 - sparse_categorical_accuracy: 0.7979 - val_loss: 0.9377 - val_sparse_categorical_accuracy: 0.4577 - lr: 0.0010
# Epoch 5/50
# 90/90 [==============================] - 6s 71ms/step - loss: 0.4089 - sparse_categorical_accuracy: 0.8066 - val_loss: 0.8820 - val_sparse_categorical_accuracy: 0.5284 - lr: 0.0010
# Epoch 6/50
# 90/90 [==============================] - 7s 73ms/step - loss: 0.4082 - sparse_categorical_accuracy: 0.8035 - val_loss: 0.7020 - val_sparse_categorical_accuracy: 0.6158 - lr: 0.0010
# Epoch 7/50
# 90/90 [==============================] - 6s 70ms/step - loss: 0.4058 - sparse_categorical_accuracy: 0.7990 - val_loss: 0.4217 - val_sparse_categorical_accuracy: 0.7642 - lr: 0.0010
# Epoch 8/50
# 90/90 [==============================] - 6s 68ms/step - loss: 0.3832 - sparse_categorical_accuracy: 0.8118 - val_loss: 0.4337 - val_sparse_categorical_accuracy: 0.7226 - lr: 0.0010
# Epoch 9/50
# 90/90 [==============================] - 6s 64ms/step - loss: 0.3875 - sparse_categorical_accuracy: 0.8087 - val_loss: 0.4674 - val_sparse_categorical_accuracy: 0.7933 - lr: 0.0010
# Epoch 10/50
# 90/90 [==============================] - 6s 65ms/step - loss: 0.3719 - sparse_categorical_accuracy: 0.8240 - val_loss: 0.3909 - val_sparse_categorical_accuracy: 0.8252 - lr: 0.0010
# Epoch 11/50
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3753 - sparse_categorical_accuracy: 0.8160 - val_loss: 0.7346 - val_sparse_categorical_accuracy: 0.6366 - lr: 0.0010
# Epoch 12/50
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3609 - sparse_categorical_accuracy: 0.8351 - val_loss: 0.3734 - val_sparse_categorical_accuracy: 0.8280 - lr: 0.0010
# Epoch 13/50
# 90/90 [==============================] - 6s 66ms/step - loss: 0.3515 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.8839 - val_sparse_categorical_accuracy: 0.6796 - lr: 0.0010
# Epoch 14/50
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3586 - sparse_categorical_accuracy: 0.8361 - val_loss: 0.5323 - val_sparse_categorical_accuracy: 0.6949 - lr: 0.0010
# Epoch 15/50
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3560 - sparse_categorical_accuracy: 0.8368 - val_loss: 0.3707 - val_sparse_categorical_accuracy: 0.8322 - lr: 0.0010
# Epoch 16/50
# 90/90 [==============================] - 6s 64ms/step - loss: 0.3469 - sparse_categorical_accuracy: 0.8431 - val_loss: 0.4515 - val_sparse_categorical_accuracy: 0.7670 - lr: 0.0010
# Epoch 17/50
# 90/90 [==============================] - 6s 66ms/step - loss: 0.3370 - sparse_categorical_accuracy: 0.8469 - val_loss: 0.4683 - val_sparse_categorical_accuracy: 0.7642 - lr: 0.0010
# Epoch 18/50
# 90/90 [==============================] - 6s 66ms/step - loss: 0.3346 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.3530 - val_sparse_categorical_accuracy: 0.8183 - lr: 0.0010
# Epoch 19/50
# 90/90 [==============================] - 6s 67ms/step - loss: 0.3339 - sparse_categorical_accuracy: 0.8458 - val_loss: 0.6029 - val_sparse_categorical_accuracy: 0.6671 - lr: 0.0010
# Epoch 20/50
# 90/90 [==============================] - 6s 65ms/step - loss: 0.3246 - sparse_categorical_accuracy: 0.8545 - val_loss: 0.3540 - val_sparse_categorical_accuracy: 0.8086 - lr: 0.0010
# Epoch 21/50
# 90/90 [==============================] - 6s 69ms/step - loss: 0.3274 - sparse_categorical_accuracy: 0.8580 - val_loss: 0.3849 - val_sparse_categorical_accuracy: 0.8086 - lr: 0.0010
# Epoch 22/50
# 90/90 [==============================] - 7s 74ms/step - loss: 0.3027 - sparse_categorical_accuracy: 0.8764 - val_loss: 0.3717 - val_sparse_categorical_accuracy: 0.8128 - lr: 0.0010
# Epoch 23/50
# 90/90 [==============================] - 6s 72ms/step - loss: 0.3002 - sparse_categorical_accuracy: 0.8677 - val_loss: 0.3820 - val_sparse_categorical_accuracy: 0.8044 - lr: 0.0010
# Epoch 24/50
# 90/90 [==============================] - 7s 75ms/step - loss: 0.3045 - sparse_categorical_accuracy: 0.8646 - val_loss: 0.3027 - val_sparse_categorical_accuracy: 0.8807 - lr: 0.0010
# Epoch 25/50
# 90/90 [==============================] - 6s 69ms/step - loss: 0.2910 - sparse_categorical_accuracy: 0.8802 - val_loss: 0.3987 - val_sparse_categorical_accuracy: 0.7836 - lr: 0.0010
# Epoch 26/50
# 90/90 [==============================] - 7s 73ms/step - loss: 0.2844 - sparse_categorical_accuracy: 0.8847 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8363 - lr: 0.0010
# Epoch 27/50
# 90/90 [==============================] - 6s 70ms/step - loss: 0.2887 - sparse_categorical_accuracy: 0.8806 - val_loss: 0.2883 - val_sparse_categorical_accuracy: 0.8821 - lr: 0.0010
# Epoch 28/50
# 90/90 [==============================] - 6s 69ms/step - loss: 0.2783 - sparse_categorical_accuracy: 0.8854 - val_loss: 0.6658 - val_sparse_categorical_accuracy: 0.6408 - lr: 0.0010
# Epoch 29/50
# 90/90 [==============================] - 6s 71ms/step - loss: 0.2727 - sparse_categorical_accuracy: 0.8861 - val_loss: 0.8029 - val_sparse_categorical_accuracy: 0.6477 - lr: 0.0010
# Epoch 30/50
# 90/90 [==============================] - 6s 68ms/step - loss: 0.2738 - sparse_categorical_accuracy: 0.8833 - val_loss: 0.7382 - val_sparse_categorical_accuracy: 0.6768 - lr: 0.0010
# Epoch 31/50
# 90/90 [==============================] - 7s 77ms/step - loss: 0.2657 - sparse_categorical_accuracy: 0.8938 - val_loss: 0.4898 - val_sparse_categorical_accuracy: 0.7781 - lr: 0.0010
# Epoch 32/50
# 90/90 [==============================] - 6s 70ms/step - loss: 0.2732 - sparse_categorical_accuracy: 0.8899 - val_loss: 0.2891 - val_sparse_categorical_accuracy: 0.8613 - lr: 0.0010
# Epoch 33/50
# 90/90 [==============================] - 5s 60ms/step - loss: 0.2641 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.2903 - val_sparse_categorical_accuracy: 0.8682 - lr: 0.0010
# Epoch 34/50
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2572 - sparse_categorical_accuracy: 0.8997 - val_loss: 0.5142 - val_sparse_categorical_accuracy: 0.7254 - lr: 0.0010
# Epoch 35/50
# 90/90 [==============================] - 6s 69ms/step - loss: 0.2781 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.3107 - val_sparse_categorical_accuracy: 0.8544 - lr: 0.0010
# Epoch 36/50
# 90/90 [==============================] - 7s 83ms/step - loss: 0.2630 - sparse_categorical_accuracy: 0.8892 - val_loss: 0.2519 - val_sparse_categorical_accuracy: 0.9057 - lr: 0.0010
# Epoch 37/50
# 90/90 [==============================] - 7s 78ms/step - loss: 0.2454 - sparse_categorical_accuracy: 0.9007 - val_loss: 0.4405 - val_sparse_categorical_accuracy: 0.7753 - lr: 0.0010
# Epoch 38/50
# 90/90 [==============================] - 6s 71ms/step - loss: 0.2635 - sparse_categorical_accuracy: 0.8896 - val_loss: 0.2631 - val_sparse_categorical_accuracy: 0.8918 - lr: 0.0010
# Epoch 39/50
# 90/90 [==============================] - 6s 69ms/step - loss: 0.2580 - sparse_categorical_accuracy: 0.8878 - val_loss: 0.2750 - val_sparse_categorical_accuracy: 0.8849 - lr: 0.0010
# Epoch 40/50
# 90/90 [==============================] - 6s 64ms/step - loss: 0.2636 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.3721 - val_sparse_categorical_accuracy: 0.7864 - lr: 0.0010
# Epoch 41/50
# 90/90 [==============================] - 5s 60ms/step - loss: 0.2526 - sparse_categorical_accuracy: 0.8962 - val_loss: 0.2724 - val_sparse_categorical_accuracy: 0.8641 - lr: 0.0010
# Epoch 42/50
# 90/90 [==============================] - 5s 60ms/step - loss: 0.2361 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.2776 - val_sparse_categorical_accuracy: 0.8807 - lr: 0.0010
# Epoch 43/50
# 90/90 [==============================] - 6s 61ms/step - loss: 0.2498 - sparse_categorical_accuracy: 0.8944 - val_loss: 0.8792 - val_sparse_categorical_accuracy: 0.6588 - lr: 0.0010
# Epoch 44/50
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2330 - sparse_categorical_accuracy: 0.9052 - val_loss: 0.3107 - val_sparse_categorical_accuracy: 0.8447 - lr: 0.0010
# Epoch 45/50
# 90/90 [==============================] - 6s 63ms/step - loss: 0.2432 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.3667 - val_sparse_categorical_accuracy: 0.8225 - lr: 0.0010
# Epoch 46/50
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2339 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.5584 - val_sparse_categorical_accuracy: 0.7171 - lr: 0.0010
# Epoch 47/50
# 90/90 [==============================] - 6s 64ms/step - loss: 0.2301 - sparse_categorical_accuracy: 0.9073 - val_loss: 1.9373 - val_sparse_categorical_accuracy: 0.6144 - lr: 0.0010
# Epoch 48/50
# 90/90 [==============================] - 6s 65ms/step - loss: 0.2310 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.9880 - val_sparse_categorical_accuracy: 0.6782 - lr: 0.0010
# Epoch 49/50
# 90/90 [==============================] - 5s 61ms/step - loss: 0.2402 - sparse_categorical_accuracy: 0.8934 - val_loss: 1.5817 - val_sparse_categorical_accuracy: 0.6117 - lr: 0.0010
# Epoch 50/50
# 90/90 [==============================] - 5s 60ms/step - loss: 0.2439 - sparse_categorical_accuracy: 0.8983 - val_loss: 0.2526 - val_sparse_categorical_accuracy: 0.8877 - lr: 0.0010

# %%
"""
## Evaluate model on test data
"""

model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 1s 9ms/step - loss: 0.2443 - sparse_categorical_accuracy: 0.9144
# Test accuracy 0.914393961429596
# Test loss 0.24428699910640717

# %%
"""
## Plot the model's training and validation loss
"""

metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

"""
We can see how the training accuracy reaches almost 0.95 after 100 epochs.
However, by observing the validation accuracy we can see how the network still needs
training until it reaches almost 0.97 for both the validation and the training accuracy
after 200 epochs. Beyond the 200th epoch, if we continue on training, the validation
accuracy will start decreasing while the training accuracy will continue on increasing:
the model starts overfitting.
"""
# Out:
# '\nWe can see how the training accuracy reaches almost 0.95 after 100 epochs.\nHowever, by observing the validation accuracy we can see how the network still needs\ntraining until it reaches almost 0.97 for both the validation and the training accuracy\nafter 200 epochs. Beyond the 200th epoch, if we continue on training, the validation\naccuracy will start decreasing while the training accuracy will continue on increasing:\nthe model starts overfitting.\n'
